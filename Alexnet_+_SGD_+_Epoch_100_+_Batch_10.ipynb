# %%
from google.colab import drive
drive.mount('/content/drive')



#此部分尚需重新执行
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np

train_on_gpu=torch.cuda.is_available()

from torchvision import datasets
from torchvision.transforms import transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

number_of_workers = 0
batch_size= 10
valid_size= 0.2

#  Converting Data into a Normalized Tensor format
transform = transforms.Compose([
                                transforms.RandomHorizontalFlip(),
                                transforms.RandomRotation(10),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=(0.5, 0.5, 0.5), std= (0.5, 0.5, 0.5))
])

train_data= datasets.CIFAR10('data', train= True, download= True, transform = transform)
test_data = datasets.CIFAR10('data', train = False, download = True, transform= transform)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data\cifar-10-python.tar.gz
# 100.0%
# Extracting data\cifar-10-python.tar.gz to data
# Files already downloaded and verified

# %%
# Obtaining training Indices that we are going to use for Validation Set
num_train= len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
# 打乱索引顺序
split = int(np.floor(valid_size * num_train))
# 划分训练和验证
train_idx, valid_idx = indices[split:] , indices[:split]
# Defining samplers for training and validation Bathces
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)
# Preparing Data Loader for all three sets (combining datasets and samplers)
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size ,
                                           sampler= train_sampler , num_workers = number_of_workers)
valid_loader= torch.utils.data.DataLoader(train_data , batch_size= batch_size,
                                          sampler = valid_sampler, num_workers = number_of_workers)
test_loader= torch.utils.data.DataLoader(test_data, batch_size= batch_size,
                                         num_workers= number_of_workers)

class_names =['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']

# %%
class AlexNet(nn.Module):
    def __init__(self):
        super(AlexNet, self).__init__()
        self.Conv = nn.Sequential(
            # IN : 3*32*32
            nn.Conv2d(in_channels=3,out_channels=96,kernel_size=5,stride=2,padding=2),
            nn.ReLU(),
            # IN : 96*16*16
            nn.MaxPool2d(kernel_size=2,stride=2),
            # IN : 96*8*8
            nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            # IN :256*8*8
            nn.MaxPool2d(kernel_size=2,stride=2),
            # IN : 256*4*4
            nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # IN : 384*4*4
            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # IN : 384*4*4
            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            # IN : 384*4*4
            nn.MaxPool2d(kernel_size=2, stride=2),
            # OUT : 384*2*2
        )
        # Old Version without dropout
        # self.linear = nn.Sequential(
        #     nn.Linear(in_features=384 * 2 * 2, out_features=4096),
        #     nn.ReLU(),
        #     nn.Linear(in_features=4096, out_features=4096),
        #     nn.ReLU(),
        #     nn.Linear(in_features=4096, out_features=10),
        # )
        # New Version with dropout
        self.dropout = nn.Dropout(p=0.5) #Dropout layer with p=0.5
        self.linear = nn.Sequential(
            nn.Linear(in_features=384 * 2 * 2, out_features=4096),
            nn.ReLU(),
            self.dropout,
            nn.Linear(in_features=4096, out_features=4096),
            nn.ReLU(),
            self.dropout,
            nn.Linear(in_features=4096, out_features=10),
        )
    def forward(self,x):
            x = self.Conv(x)
            x = x.view(-1, 384 * 2 * 2)
            x = self.linear(x)
            return x


# create a complete CNN
model = AlexNet()
print(model)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# AlexNet(
#   (Conv): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear): Sequential(
#     (0): Linear(in_features=1536, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
#SGD
optimizer = optim.SGD(model.parameters(), lr= 0.0001, momentum= 0.9)

#Adam
# optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=5e-4)

# number of epochs to train the model
n_epochs = 100  # you may increase this number to train a final model

valid_loss_min = np.Inf  # track change in validation loss


train_losses = []
valid_losses = []


for epoch in range(1, n_epochs + 1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    # train the model #
    ###################
    model.train()
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item() * data.size(0)

    ######################
    # validate the model #
    ######################
    model.eval()
    for data, target in valid_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss
        valid_loss += loss.item() * data.size(0)

    # # calculate average losses
    # train_loss = train_loss / len(train_loader.dataset)
    # valid_loss = valid_loss / len(valid_loader.dataset)
    #
    # # print training/validation statistics
    # print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
    #     epoch, train_loss, valid_loss))

    train_loss = train_loss / len(train_loader.dataset)
    valid_loss = valid_loss / len(valid_loader.dataset)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))


    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss

plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.title("Training and Validation Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch: 1 	Training Loss: 1.842077 	Validation Loss: 0.460500
# Validation loss decreased (inf --> 0.460500).  Saving model ...
# Epoch: 2 	Training Loss: 1.841870 	Validation Loss: 0.460475
# Validation loss decreased (0.460500 --> 0.460475).  Saving model ...
# Epoch: 3 	Training Loss: 1.841762 	Validation Loss: 0.460422
# Validation loss decreased (0.460475 --> 0.460422).  Saving model ...
# Epoch: 4 	Training Loss: 1.841435 	Validation Loss: 0.460332
# Validation loss decreased (0.460422 --> 0.460332).  Saving model ...
# Epoch: 5 	Training Loss: 1.841002 	Validation Loss: 0.460172
# Validation loss decreased (0.460332 --> 0.460172).  Saving model ...
# Epoch: 6 	Training Loss: 1.840130 	Validation Loss: 0.459824
# Validation loss decreased (0.460172 --> 0.459824).  Saving model ...
# Epoch: 7 	Training Loss: 1.838034 	Validation Loss: 0.458736
# Validation loss decreased (0.459824 --> 0.458736).  Saving model ...
# Epoch: 8 	Training Loss: 1.826475 	Validation Loss: 0.450181
# Validation loss decreased (0.458736 --> 0.450181).  Saving model ...
# Epoch: 9 	Training Loss: 1.718210 	Validation Loss: 0.400754
# Validation loss decreased (0.450181 --> 0.400754).  Saving model ...
# Epoch: 10 	Training Loss: 1.576766 	Validation Loss: 0.378408
# Validation loss decreased (0.400754 --> 0.378408).  Saving model ...
# Epoch: 11 	Training Loss: 1.517066 	Validation Loss: 0.369022
# Validation loss decreased (0.378408 --> 0.369022).  Saving model ...
# Epoch: 12 	Training Loss: 1.480782 	Validation Loss: 0.359837
# Validation loss decreased (0.369022 --> 0.359837).  Saving model ...
# Epoch: 13 	Training Loss: 1.445538 	Validation Loss: 0.351235
# Validation loss decreased (0.359837 --> 0.351235).  Saving model ...
# Epoch: 14 	Training Loss: 1.400866 	Validation Loss: 0.341837
# Validation loss decreased (0.351235 --> 0.341837).  Saving model ...
# Epoch: 15 	Training Loss: 1.354234 	Validation Loss: 0.328319
# Validation loss decreased (0.341837 --> 0.328319).  Saving model ...
# Epoch: 16 	Training Loss: 1.301443 	Validation Loss: 0.313132
# Validation loss decreased (0.328319 --> 0.313132).  Saving model ...
# Epoch: 17 	Training Loss: 1.249627 	Validation Loss: 0.299175
# Validation loss decreased (0.313132 --> 0.299175).  Saving model ...
# Epoch: 18 	Training Loss: 1.199542 	Validation Loss: 0.293229
# Validation loss decreased (0.299175 --> 0.293229).  Saving model ...
# Epoch: 19 	Training Loss: 1.159519 	Validation Loss: 0.304330
# Epoch: 20 	Training Loss: 1.123836 	Validation Loss: 0.269785
# Validation loss decreased (0.293229 --> 0.269785).  Saving model ...
# Epoch: 21 	Training Loss: 1.089268 	Validation Loss: 0.260871
# Validation loss decreased (0.269785 --> 0.260871).  Saving model ...
# Epoch: 22 	Training Loss: 1.054698 	Validation Loss: 0.256414
# Validation loss decreased (0.260871 --> 0.256414).  Saving model ...
# Epoch: 23 	Training Loss: 1.027104 	Validation Loss: 0.254977
# Validation loss decreased (0.256414 --> 0.254977).  Saving model ...
# Epoch: 24 	Training Loss: 1.000466 	Validation Loss: 0.248826
# Validation loss decreased (0.254977 --> 0.248826).  Saving model ...
# Epoch: 25 	Training Loss: 0.970232 	Validation Loss: 0.247076
# Validation loss decreased (0.248826 --> 0.247076).  Saving model ...
# Epoch: 26 	Training Loss: 0.946560 	Validation Loss: 0.237262
# Validation loss decreased (0.247076 --> 0.237262).  Saving model ...
# Epoch: 27 	Training Loss: 0.917931 	Validation Loss: 0.224956
# Validation loss decreased (0.237262 --> 0.224956).  Saving model ...
# Epoch: 28 	Training Loss: 0.898971 	Validation Loss: 0.223082
# Validation loss decreased (0.224956 --> 0.223082).  Saving model ...
# Epoch: 29 	Training Loss: 0.877116 	Validation Loss: 0.223523
# Epoch: 30 	Training Loss: 0.857094 	Validation Loss: 0.216130
# Validation loss decreased (0.223082 --> 0.216130).  Saving model ...
# Epoch: 31 	Training Loss: 0.835940 	Validation Loss: 0.213876
# Validation loss decreased (0.216130 --> 0.213876).  Saving model ...
# Epoch: 32 	Training Loss: 0.819250 	Validation Loss: 0.220869
# Epoch: 33 	Training Loss: 0.799112 	Validation Loss: 0.207819
# Validation loss decreased (0.213876 --> 0.207819).  Saving model ...
# Epoch: 34 	Training Loss: 0.783544 	Validation Loss: 0.199335
# Validation loss decreased (0.207819 --> 0.199335).  Saving model ...
# Epoch: 35 	Training Loss: 0.768813 	Validation Loss: 0.199215
# Validation loss decreased (0.199335 --> 0.199215).  Saving model ...
# Epoch: 36 	Training Loss: 0.751597 	Validation Loss: 0.192710
# Validation loss decreased (0.199215 --> 0.192710).  Saving model ...
# Epoch: 37 	Training Loss: 0.738320 	Validation Loss: 0.191463
# Validation loss decreased (0.192710 --> 0.191463).  Saving model ...
# Epoch: 38 	Training Loss: 0.724310 	Validation Loss: 0.185813
# Validation loss decreased (0.191463 --> 0.185813).  Saving model ...
# Epoch: 39 	Training Loss: 0.705857 	Validation Loss: 0.208740
# Epoch: 40 	Training Loss: 0.697605 	Validation Loss: 0.209823
# Epoch: 41 	Training Loss: 0.681976 	Validation Loss: 0.189797
# Epoch: 42 	Training Loss: 0.671973 	Validation Loss: 0.178265
# Validation loss decreased (0.185813 --> 0.178265).  Saving model ...
# Epoch: 43 	Training Loss: 0.661288 	Validation Loss: 0.177651
# Validation loss decreased (0.178265 --> 0.177651).  Saving model ...
# Epoch: 44 	Training Loss: 0.644379 	Validation Loss: 0.175509
# Validation loss decreased (0.177651 --> 0.175509).  Saving model ...
# Epoch: 45 	Training Loss: 0.634857 	Validation Loss: 0.174111
# Validation loss decreased (0.175509 --> 0.174111).  Saving model ...
# Epoch: 46 	Training Loss: 0.620381 	Validation Loss: 0.175578
# Epoch: 47 	Training Loss: 0.610874 	Validation Loss: 0.175895
# Epoch: 48 	Training Loss: 0.597563 	Validation Loss: 0.177928
# Epoch: 49 	Training Loss: 0.588594 	Validation Loss: 0.172086
# Validation loss decreased (0.174111 --> 0.172086).  Saving model ...
# Epoch: 50 	Training Loss: 0.577155 	Validation Loss: 0.173633
# Epoch: 51 	Training Loss: 0.567443 	Validation Loss: 0.170550
# Validation loss decreased (0.172086 --> 0.170550).  Saving model ...
# Epoch: 52 	Training Loss: 0.556419 	Validation Loss: 0.175406
# Epoch: 53 	Training Loss: 0.547198 	Validation Loss: 0.164229
# Validation loss decreased (0.170550 --> 0.164229).  Saving model ...
# Epoch: 54 	Training Loss: 0.540165 	Validation Loss: 0.173264
# Epoch: 55 	Training Loss: 0.526552 	Validation Loss: 0.164592
# Epoch: 56 	Training Loss: 0.517199 	Validation Loss: 0.168578
# Epoch: 57 	Training Loss: 0.505112 	Validation Loss: 0.165698
# Epoch: 58 	Training Loss: 0.499672 	Validation Loss: 0.167265
# Epoch: 59 	Training Loss: 0.488396 	Validation Loss: 0.161607
# Validation loss decreased (0.164229 --> 0.161607).  Saving model ...
# Epoch: 60 	Training Loss: 0.479367 	Validation Loss: 0.167472
# Epoch: 61 	Training Loss: 0.472004 	Validation Loss: 0.160413
# Validation loss decreased (0.161607 --> 0.160413).  Saving model ...
# Epoch: 62 	Training Loss: 0.462624 	Validation Loss: 0.162017
# Epoch: 63 	Training Loss: 0.455217 	Validation Loss: 0.159010
# Validation loss decreased (0.160413 --> 0.159010).  Saving model ...
# Epoch: 64 	Training Loss: 0.444738 	Validation Loss: 0.163091
# Epoch: 65 	Training Loss: 0.435597 	Validation Loss: 0.159605
# Epoch: 66 	Training Loss: 0.431844 	Validation Loss: 0.157987
# Validation loss decreased (0.159010 --> 0.157987).  Saving model ...
# Epoch: 67 	Training Loss: 0.417699 	Validation Loss: 0.168948
# Epoch: 68 	Training Loss: 0.409667 	Validation Loss: 0.165734
# Epoch: 69 	Training Loss: 0.404535 	Validation Loss: 0.160504
# Epoch: 70 	Training Loss: 0.397348 	Validation Loss: 0.165038
# Epoch: 71 	Training Loss: 0.388418 	Validation Loss: 0.162480
# Epoch: 72 	Training Loss: 0.382697 	Validation Loss: 0.168469
# Epoch: 73 	Training Loss: 0.376183 	Validation Loss: 0.173220
# Epoch: 74 	Training Loss: 0.367559 	Validation Loss: 0.168222
# Epoch: 75 	Training Loss: 0.359568 	Validation Loss: 0.166156
# Epoch: 76 	Training Loss: 0.350194 	Validation Loss: 0.170295
# Epoch: 77 	Training Loss: 0.347455 	Validation Loss: 0.167334
# Epoch: 78 	Training Loss: 0.339276 	Validation Loss: 0.169119
# Epoch: 79 	Training Loss: 0.330622 	Validation Loss: 0.167437
# Epoch: 80 	Training Loss: 0.324756 	Validation Loss: 0.163536
# Epoch: 81 	Training Loss: 0.317696 	Validation Loss: 0.169642
# Epoch: 82 	Training Loss: 0.311384 	Validation Loss: 0.173721
# Epoch: 83 	Training Loss: 0.303309 	Validation Loss: 0.169428
# Epoch: 84 	Training Loss: 0.295340 	Validation Loss: 0.182795
# Epoch: 85 	Training Loss: 0.293551 	Validation Loss: 0.168544
# Epoch: 86 	Training Loss: 0.283629 	Validation Loss: 0.168614
# Epoch: 87 	Training Loss: 0.280327 	Validation Loss: 0.177791
# Epoch: 88 	Training Loss: 0.272146 	Validation Loss: 0.176853
# Epoch: 89 	Training Loss: 0.264317 	Validation Loss: 0.169156
# Epoch: 90 	Training Loss: 0.259513 	Validation Loss: 0.169678
# Epoch: 91 	Training Loss: 0.254650 	Validation Loss: 0.174417
# Epoch: 92 	Training Loss: 0.253945 	Validation Loss: 0.187551
# Epoch: 93 	Training Loss: 0.245461 	Validation Loss: 0.168797
# Epoch: 94 	Training Loss: 0.238030 	Validation Loss: 0.172959
# Epoch: 95 	Training Loss: 0.232154 	Validation Loss: 0.177397
# Epoch: 96 	Training Loss: 0.227195 	Validation Loss: 0.177122
# Epoch: 97 	Training Loss: 0.219545 	Validation Loss: 0.177356
# Epoch: 98 	Training Loss: 0.217416 	Validation Loss: 0.178322
# Epoch: 99 	Training Loss: 0.209100 	Validation Loss: 0.186692
# Epoch: 100 	Training Loss: 0.204029 	Validation Loss: 0.182451

# %%
model.load_state_dict(torch.load('model_cifar.pt'))

# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

y_true = []
y_pred = []


model.eval()
# iterate over test data
for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)


    y_true.extend(target.cpu().numpy())
    y_pred.extend(pred.cpu().numpy())
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            class_names[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (class_names[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.818037
#
# Test Accuracy of airplane: 74% (740/1000)
# Test Accuracy of automobile: 81% (815/1000)
# Test Accuracy of  bird: 67% (672/1000)
# Test Accuracy of   cat: 49% (491/1000)
# Test Accuracy of  deer: 67% (676/1000)
# Test Accuracy of   dog: 60% (600/1000)
# Test Accuracy of  frog: 77% (777/1000)
# Test Accuracy of horse: 79% (798/1000)
# Test Accuracy of  ship: 86% (868/1000)
# Test Accuracy of truck: 82% (823/1000)
#
# Test Accuracy (Overall): 72% (7260/10000)

# %%
# Increase the size of the confusion matrix display
plt.figure()

confusionM = confusion_matrix(y_true, y_pred)
displayCM = ConfusionMatrixDisplay(confusion_matrix=confusionM, display_labels=class_names)

# Use a different colormap
displayCM.plot(cmap=plt.cm.Blues)  # You can change Greens to any other colormap like Reds, Blues, etc.

plt.title("Confusion Matrix")
plt.xlabel('Predicted label')
plt.ylabel('True label')

# Rotate the x-axis labels so they don't overlap
plt.xticks(rotation=45)

plt.show()

# %%
new_test_loader= torch.utils.data.DataLoader(test_data, batch_size= 100,
                                         num_workers= number_of_workers)

#draw the classified imgaes result and confidence
def imshow(img):
    img = img / 2 + 0.5  # unnormalize if the images were normalized
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))  # Convert from tensor image

# Obtain one batch of test images
dataiter = iter(new_test_loader)
images, labels = next(dataiter)

# Move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# Get sample outputs
output = model(images)
# Convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.cpu().numpy())

# Get the probabilities for the predictions
probabilities = torch.nn.functional.softmax(output, dim=1)
confidences = np.max(probabilities.cpu().detach().numpy(), axis=1)

# Plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 20))
for idx in np.arange(100):
    ax = fig.add_subplot(10, 10, idx+1, xticks=[], yticks=[])
    imshow(images[idx].cpu())  # Use your image display function here
    title_color = "green" if preds[idx]==labels[idx].item() else "red"
    # Set the title with class names
    ax.set_title("{0} ({1})".format(class_names[preds[idx]], class_names[labels[idx]]), color=title_color)
    # Set the confidence below the image
    ax.text(0.5, -0.2, "Confidence: {0:.1f}%".format(confidences[idx]*100),
            ha='center', va='top', transform=ax.transAxes, color=title_color)
    # Adjust the subplot parameters to give specified padding
    plt.subplots_adjust(hspace=0.8, wspace=0.3)
plt.show()
